# %%
#Basketball packages
print("Welcome to my grocery store!")
print()

print("Are you a Priceplus Member?")
print()


member = input("Yes or No").lower()
while member == "no":
    print("Please see store associate for savings sign up.")
else:
    print("Welcome back shopper.")

# print("""
# ____Shopping Cart_____
# 1. Add items
# 2. Remove items
# 3. View items in cart
# 0. Exit cart

# """)
    
# option = int(input("Enter an option: "))    

# while option != 0:
#     if option == 1:
#         item = input("Select an item: ")
        
    
#     elif option == 2:
#         item = input("Enter an item: ")
#         del(cart[item])
        
#     elif option == 3:
#         for item in cart:
#             print(item,":", cart[item])
            
#     elif option != 0:
#         print("Not a valid number. ")
        
#     option = int(input("\n\nEnter an option: "))
    
inventory = {"apples": .75,
            "oranges": 1.25,
            "bannanas": 1.00,
            "bread": 1.50,
            "onions": .75,
            "ice cream": 1.25,
            "bagels": 1.00,
            "carrots": 1.50,
             "butter": .75,
            "crackers": 1.25,
            "yogurt": 1.00,
            "bread": 1.50}

cart = []
total = 0

for key, value in inventory.items():
    print(f"{key} : ${value:.2f}")

while True:
    food = input("Choose your groceries (q to quit): ").lower()
    if food == "q":
        break
    elif inventory.get(food) is not None:
        cart.append(food)
    
for food in cart:
    total = total + inventory.get(food)
    print(food)
    
print(f"Your total is: ${total}")
# Out:
# Welcome to my grocery store!
#
# Are you a Priceplus Member?
#
# Yes or Nono
# Welcome back shopper.
# apples : $0.75
# oranges : $1.25
# bannanas : $1.00
# bread : $1.50
# onions : $0.75
# ice cream : $1.25
# bagels : $1.00
# carrots : $1.50
# butter : $0.75
# crackers : $1.25
# yogurt : $1.00
# Choose your groceries (q to quit): butter
# Choose your groceries (q to quit): apples
# Choose your groceries (q to quit): crackers
# Choose your groceries (q to quit): ice cream
# Choose your groceries (q to quit): q
# butter
# apples
# crackers
# ice cream
# Your total is: $4.0
